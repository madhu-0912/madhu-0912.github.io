# %%
import pandas as pd
import numpy as np
import os
import calendar
from pathlib import Path # to interact with file system.
import networkx as nx
from pandas.plotting import scatter_matrix, parallel_coordinates
import seaborn as sns # Making statistical graphs on top of what matplot can do 
from sklearn import preprocessing
from sklearn.metrics import jaccard_score
import matplotlib.pylab as plt # %matplotlib inline renders the figure in a notebook

# %%
df = pd.read_csv("dataBAN620-finalproj.csv")
df.head()
# Out:
#                                            Indicator ValueType  \
# 0  nMx - age-specific death rate between ages x a...   numeric
# 1  nMx - age-specific death rate between ages x a...   numeric
# 2  nMx - age-specific death rate between ages x a...   numeric
# 3  nMx - age-specific death rate between ages x a...   numeric
# 4  nMx - age-specific death rate between ages x a...   numeric
#
#   ParentLocationCode ParentLocation Location type SpatialDimValueCode  \
# 0                EUR         Europe       Country                 DNK
# 1                EUR         Europe       Country                 ISL
# 2                EUR         Europe       Country                 ISL
# 3                EUR         Europe       Country                 ISR
# 4                EUR         Europe       Country                 LUX
#
#      Location Period type  Period  IsLatestYear  ... FactValueUoM  \
# 0     Denmark        Year    2019          True  ...          NaN
# 1     Iceland        Year    2019          True  ...          NaN
# 2     Iceland        Year    2019          True  ...          NaN
# 3      Israel        Year    2019          True  ...          NaN
# 4  Luxembourg        Year    2019          True  ...          NaN
#
#   FactValueNumericLowPrefix FactValueNumericLow FactValueNumericHighPrefix  \
# 0                       NaN                 NaN                        NaN
# 1                       NaN                 NaN                        NaN
# 2                       NaN                 NaN                        NaN
# 3                       NaN                 NaN                        NaN
# 4                       NaN                 NaN                        NaN
#
#   FactValueNumericHigh Value  FactValueTranslationID  FactComments  Language  \
# 0                  NaN     0                     NaN           NaN        EN
# 1                  NaN     0                     NaN           NaN        EN
# 2                  NaN     0                     NaN           NaN        EN
# 3                  NaN     0                     NaN           NaN        EN
# 4                  NaN     0                     NaN           NaN        EN
#
#                DateModified
# 0  2020-12-06T08:00:00.000Z
# 1  2020-12-06T08:00:00.000Z
# 2  2020-12-06T08:00:00.000Z
# 3  2020-12-06T08:00:00.000Z
# 4  2020-12-06T08:00:00.000Z
#
# [5 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['Indicator', 'ValueType', 'ParentLocationCode', 'ParentLocation',
#        'Location type', 'SpatialDimValueCode', 'Location', 'Period type',
#        'Period', 'IsLatestYear', 'Dim1 type', 'Dim1', 'Dim1ValueCode',
#        'Dim2 type', 'Dim2', 'Dim2ValueCode', 'Dim3 type', 'Dim3',
#        'Dim3ValueCode', 'DataSourceDimValueCode', 'DataSource',
#        'FactValueNumericPrefix', 'FactValueNumeric', 'FactValueUoM',
#        'FactValueNumericLowPrefix', 'FactValueNumericLow',
#        'FactValueNumericHighPrefix', 'FactValueNumericHigh', 'Value',
#        'FactValueTranslationID', 'FactComments', 'Language', 'DateModified'],
#       dtype='object')

# %%
df= df[['Indicator','ParentLocationCode','SpatialDimValueCode', 'Location','Period','Dim1','Dim2','FactValueNumeric']]
df.columns
# Out:
# Index(['Indicator', 'ParentLocationCode', 'SpatialDimValueCode', 'Location',
#        'Period', 'Dim1', 'Dim2', 'FactValueNumeric'],
#       dtype='object')

# %%
ten_economies=['China','United States of America','India','Japan','Germany','Russian Federation','Brazil','Indonesia','United Kingdom of Great Britain and Northern Ireland','France','Mexico']
#its going to 11 countries

# %%
df=df[df['Location'].isin(ten_economies)]

# %% [markdown]
# ['China','United States of America','India','Japan','Germany','Russian Federation','Brazil','Indonesia','United Kingdom of Great Britain and Northern Ireland','France','Mexico']

# %%
df.columns = [s.strip().replace(' ', '_') for s in df.columns]
df=df.rename(columns={'Dim1':'Sex','Dim2':'Age_Group','ParentLocationCode':'Region_Code'})
df=df.sort_values(by=['Location','Period','Age_Group','Sex'])

# %%
df.columns
# Out:
# Index(['Indicator', 'Region_Code', 'SpatialDimValueCode', 'Location', 'Period',
#        'Sex', 'Age_Group', 'FactValueNumeric'],
#       dtype='object')

# %%
df1 = pd.get_dummies(df['Indicator'], prefix_sep='_', drop_first=True)
df1
# Out:
#         ex - expectation of life at age x  \
# 195954                                  0
# 202660                                  0
# 214506                                  0
# 219508                                  0
# 224970                                  0
# ...                                   ...
# 14269                                   0
# 26205                                   0
# 34670                                   0
# 41010                                   0
# 48068                                   1
#
#         lx - number of people left alive at age x  \
# 195954                                          0
# 202660                                          0
# 214506                                          1
# 219508                                          0
# 224970                                          0
# ...                                           ...
# 14269                                           1
# 26205                                           0
# 34670                                           0
# 41010                                           0
# 48068                                           0
#
#         nLx - person-years lived between ages x and x+n  \
# 195954                                                0
# 202660                                                0
# 214506                                                0
# 219508                                                0
# 224970                                                1
# ...                                                 ...
# 14269                                                 0
# 26205                                                 0
# 34670                                                 1
# 41010                                                 0
# 48068                                                 0
#
#         nMx - age-specific death rate between ages x and x+n  \
# 195954                                                  1
# 202660                                                  0
# 214506                                                  0
# 219508                                                  0
# 224970                                                  0
# ...                                                   ...
# 14269                                                   0
# 26205                                                   0
# 34670                                                   0
# 41010                                                   0
# 48068                                                   0
#
#         ndx - number of people dying between ages x and x+n  \
# 195954                                                  0
# 202660                                                  0
# 214506                                                  0
# 219508                                                  1
# 224970                                                  0
# ...                                                   ...
# 14269                                                   0
# 26205                                                   1
# 34670                                                   0
# 41010                                                   0
# 48068                                                   0
#
#         nqx - probability of dying between ages x and x+n
# 195954                                                  0
# 202660                                                  1
# 214506                                                  0
# 219508                                                  0
# 224970                                                  0
# ...                                                   ...
# 14269                                                   0
# 26205                                                   0
# 34670                                                   0
# 41010                                                   0
# 48068                                                   0
#
# [14630 rows x 6 columns]

# %%
df=df.reset_index(drop=True)
df
# Out:
#                                                Indicator Region_Code  \
# 0      nMx - age-specific death rate between ages x a...         AMR
# 1      nqx - probability of dying between ages x and x+n         AMR
# 2              lx - number of people left alive at age x         AMR
# 3      ndx - number of people dying between ages x an...         AMR
# 4        nLx - person-years lived between ages x and x+n         AMR
# ...                                                  ...         ...
# 14625          lx - number of people left alive at age x         AMR
# 14626  ndx - number of people dying between ages x an...         AMR
# 14627    nLx - person-years lived between ages x and x+n         AMR
# 14628                Tx - person-years lived above age x         AMR
# 14629                  ex - expectation of life at age x         AMR
#
#       SpatialDimValueCode                  Location  Period     Sex  \
# 0                     BRA                    Brazil    2000  Female
# 1                     BRA                    Brazil    2000  Female
# 2                     BRA                    Brazil    2000  Female
# 3                     BRA                    Brazil    2000  Female
# 4                     BRA                    Brazil    2000  Female
# ...                   ...                       ...     ...     ...
# 14625                 USA  United States of America    2019    Male
# 14626                 USA  United States of America    2019    Male
# 14627                 USA  United States of America    2019    Male
# 14628                 USA  United States of America    2019    Male
# 14629                 USA  United States of America    2019    Male
#
#        Age_Group  FactValueNumeric
# 0      1-4 years             0.001
# 1      1-4 years             0.004
# 2      1-4 years         97402.000
# 3      1-4 years           392.300
# 4      1-4 years        388666.000
# ...          ...               ...
# 14625    <1 year        100000.000
# 14626    <1 year           596.700
# 14627    <1 year         99463.000
# 14628    <1 year       7628125.000
# 14629    <1 year            76.280
#
# [14630 rows x 8 columns]

# %%
df2= df.pivot_table(index=['Region_Code', 'SpatialDimValueCode', 'Location', 'Period', 'Sex', 'Age_Group'],
                             columns='Indicator',
                             values='FactValueNumeric',
                             aggfunc='first').reset_index()
df2
# Out:
# Indicator Region_Code SpatialDimValueCode Location  Period     Sex  \
# 0                 AMR                 BRA   Brazil    2000  Female
# 1                 AMR                 BRA   Brazil    2000  Female
# 2                 AMR                 BRA   Brazil    2000  Female
# 3                 AMR                 BRA   Brazil    2000  Female
# 4                 AMR                 BRA   Brazil    2000  Female
# ...               ...                 ...      ...     ...     ...
# 2085              WPR                 JPN    Japan    2019    Male
# 2086              WPR                 JPN    Japan    2019    Male
# 2087              WPR                 JPN    Japan    2019    Male
# 2088              WPR                 JPN    Japan    2019    Male
# 2089              WPR                 JPN    Japan    2019    Male
#
# Indicator     Age_Group  Tx - person-years lived above age x  \
# 0             1-4 years                            7420561.0
# 1           10-14 years                            6547182.0
# 2          15-19  years                            6063147.0
# 3           20-24 years                            5580047.0
# 4           25-29 years                            5098299.0
# ...                 ...                                  ...
# 2085        70-74 years                            1345405.0
# 2086        75-79 years                             942929.0
# 2087        80-84 years                             588185.0
# 2088          85+ years                             305948.0
# 2089            <1 year                            8148871.0
#
# Indicator  ex - expectation of life at age x  \
# 0                                      76.18
# 1                                      67.58
# 2                                      62.68
# 3                                      57.82
# 4                                      53.00
# ...                                      ...
# 2085                                   15.97
# 2086                                   12.28
# 2087                                    9.03
# 2088                                    6.41
# 2089                                   81.49
#
# Indicator  lx - number of people left alive at age x  \
# 0                                            97402.0
# 1                                            96875.0
# 2                                            96739.0
# 3                                            96502.0
# 4                                            96197.0
# ...                                              ...
# 2085                                         84223.0
# 2086                                         76768.0
# 2087                                         65130.0
# 2088                                         47765.0
# 2089                                        100000.0
#
# Indicator  nLx - person-years lived between ages x and x+n  \
# 0                                                 388666.0
# 1                                                 484035.0
# 2                                                 483101.0
# 3                                                 481748.0
# 4                                                 480046.0
# ...                                                    ...
# 2085                                              402477.0
# 2086                                              354743.0
# 2087                                              282238.0
# 2088                                              305948.0
# 2089                                               99823.0
#
# Indicator  nMx - age-specific death rate between ages x and x+n  \
# 0                                                     0.0010
# 1                                                     0.0003
# 2                                                     0.0005
# 3                                                     0.0006
# 4                                                     0.0008
# ...                                                      ...
# 2085                                                  0.0190
# 2086                                                  0.0330
# 2087                                                  0.0620
# 2088                                                  0.1400
# 2089                                                  0.0020
#
# Indicator  ndx - number of people dying between ages x and x+n  \
# 0                                                      392.3
# 1                                                      137.0
# 2                                                      236.7
# 3                                                      304.5
# 4                                                      376.4
# ...                                                      ...
# 2085                                                  7455.0
# 2086                                                 11638.0
# 2087                                                 17364.0
# 2088                                                 47765.0
# 2089                                                   196.4
#
# Indicator  nqx - probability of dying between ages x and x+n
# 0                                                      0.004
# 1                                                      0.001
# 2                                                      0.002
# 3                                                      0.003
# 4                                                      0.004
# ...                                                      ...
# 2085                                                   0.089
# 2086                                                   0.150
# 2087                                                   0.270
# 2088                                                   1.000
# 2089                                                   0.002
#
# [2090 rows x 13 columns]

# %%
# df2=df.groupby(['Region_Code','SpatialDimValueCode','Location','Period','Sex','Age_Group'])[['Death_Rate']]
# df2

# %%
# Assuming your DataFrame is named 'df'
# Replace 'your_dataset.csv' with the actual path or URL of your dataset file
# df = pd.read_csv('your_dataset.csv')

# List of categorical columns to denormalize
categorical_columns = ['Region_Code', 'SpatialDimValueCode', 'Location', 'Sex', 'Age_Group','Indicator']

# Iterate through each categorical column and denormalize
for col in categorical_columns:
    df3 = df.pivot_table(index=[c for c in df.columns if c not in [col, 'FactValueNumeric']],
                        columns=col,
                        values='FactValueNumeric',
                        aggfunc='first').reset_index()

# Display the denormalized DataFrame
df3
# Out:
# Indicator Region_Code SpatialDimValueCode Location  Period     Sex  \
# 0                 AMR                 BRA   Brazil    2000  Female
# 1                 AMR                 BRA   Brazil    2000  Female
# 2                 AMR                 BRA   Brazil    2000  Female
# 3                 AMR                 BRA   Brazil    2000  Female
# 4                 AMR                 BRA   Brazil    2000  Female
# ...               ...                 ...      ...     ...     ...
# 2085              WPR                 JPN    Japan    2019    Male
# 2086              WPR                 JPN    Japan    2019    Male
# 2087              WPR                 JPN    Japan    2019    Male
# 2088              WPR                 JPN    Japan    2019    Male
# 2089              WPR                 JPN    Japan    2019    Male
#
# Indicator     Age_Group  Tx - person-years lived above age x  \
# 0             1-4 years                            7420561.0
# 1           10-14 years                            6547182.0
# 2          15-19  years                            6063147.0
# 3           20-24 years                            5580047.0
# 4           25-29 years                            5098299.0
# ...                 ...                                  ...
# 2085        70-74 years                            1345405.0
# 2086        75-79 years                             942929.0
# 2087        80-84 years                             588185.0
# 2088          85+ years                             305948.0
# 2089            <1 year                            8148871.0
#
# Indicator  ex - expectation of life at age x  \
# 0                                      76.18
# 1                                      67.58
# 2                                      62.68
# 3                                      57.82
# 4                                      53.00
# ...                                      ...
# 2085                                   15.97
# 2086                                   12.28
# 2087                                    9.03
# 2088                                    6.41
# 2089                                   81.49
#
# Indicator  lx - number of people left alive at age x  \
# 0                                            97402.0
# 1                                            96875.0
# 2                                            96739.0
# 3                                            96502.0
# 4                                            96197.0
# ...                                              ...
# 2085                                         84223.0
# 2086                                         76768.0
# 2087                                         65130.0
# 2088                                         47765.0
# 2089                                        100000.0
#
# Indicator  nLx - person-years lived between ages x and x+n  \
# 0                                                 388666.0
# 1                                                 484035.0
# 2                                                 483101.0
# 3                                                 481748.0
# 4                                                 480046.0
# ...                                                    ...
# 2085                                              402477.0
# 2086                                              354743.0
# 2087                                              282238.0
# 2088                                              305948.0
# 2089                                               99823.0
#
# Indicator  nMx - age-specific death rate between ages x and x+n  \
# 0                                                     0.0010
# 1                                                     0.0003
# 2                                                     0.0005
# 3                                                     0.0006
# 4                                                     0.0008
# ...                                                      ...
# 2085                                                  0.0190
# 2086                                                  0.0330
# 2087                                                  0.0620
# 2088                                                  0.1400
# 2089                                                  0.0020
#
# Indicator  ndx - number of people dying between ages x and x+n  \
# 0                                                      392.3
# 1                                                      137.0
# 2                                                      236.7
# 3                                                      304.5
# 4                                                      376.4
# ...                                                      ...
# 2085                                                  7455.0
# 2086                                                 11638.0
# 2087                                                 17364.0
# 2088                                                 47765.0
# 2089                                                   196.4
#
# Indicator  nqx - probability of dying between ages x and x+n
# 0                                                      0.004
# 1                                                      0.001
# 2                                                      0.002
# 3                                                      0.003
# 4                                                      0.004
# ...                                                      ...
# 2085                                                   0.089
# 2086                                                   0.150
# 2087                                                   0.270
# 2088                                                   1.000
# 2089                                                   0.002
#
# [2090 rows x 13 columns]

# %%
# df_merged.to_csv('final1.csv', index=True)

# %%
df3.Location.unique()
# Out:
# array(['Brazil', 'Mexico', 'United States of America', 'Germany',
#        'France', 'United Kingdom of Great Britain and Northern Ireland',
#        'Russian Federation', 'Indonesia', 'India', 'China', 'Japan'],
#       dtype=object)

# %% [markdown]
# GDP = [{'Location':['Brazil', 'Mexico', 'United States of America', 'Germany',
#        'France', 'United Kingdom of Great Britain and Northern Ireland',
#        'Russian Federation', 'Indonesia', 'India', 'China', 'Japan'],'GDP':[]}]

# %% [markdown]
# 2000, 2005, 2010, 2015, 2019

# %%
GDP_df=pd.read_csv("national-gdp-penn-world-table.csv")
GDP_df=GDP_df.drop(columns='Entity')
GDP_df= GDP_df.reset_index(drop=True)
GDP_df= GDP_df.rename(columns={"Code":"SpatialDimValueCode","Year":"Period","GDP (output, multiple price benchmarks)":"GDP"})
GDP_df
# Out:
#       SpatialDimValueCode  Period          GDP
# 0                     ALB    1971   6958496300
# 1                     ALB    1972   7246038000
# 2                     ALB    1973   7536605700
# 3                     ALB    1974   7855124000
# 4                     ALB    1975   8164371000
# ...                   ...     ...          ...
# 10103                 ZWE    2015  39798645000
# 10104                 ZWE    2016  40963190000
# 10105                 ZWE    2017  44316740000
# 10106                 ZWE    2018  43420897000
# 10107                 ZWE    2019  40826570000
#
# [10108 rows x 3 columns]

# %%
df_merged = pd.merge(df3, GDP_df, on=['SpatialDimValueCode', 'Period'], how='left')
df_merged
# Out:
#      Region_Code SpatialDimValueCode Location  Period     Sex     Age_Group  \
# 0            AMR                 BRA   Brazil    2000  Female     1-4 years
# 1            AMR                 BRA   Brazil    2000  Female   10-14 years
# 2            AMR                 BRA   Brazil    2000  Female  15-19  years
# 3            AMR                 BRA   Brazil    2000  Female   20-24 years
# 4            AMR                 BRA   Brazil    2000  Female   25-29 years
# ...          ...                 ...      ...     ...     ...           ...
# 2085         WPR                 JPN    Japan    2019    Male   70-74 years
# 2086         WPR                 JPN    Japan    2019    Male   75-79 years
# 2087         WPR                 JPN    Japan    2019    Male   80-84 years
# 2088         WPR                 JPN    Japan    2019    Male     85+ years
# 2089         WPR                 JPN    Japan    2019    Male       <1 year
#
#       Tx - person-years lived above age x  ex - expectation of life at age x  \
# 0                               7420561.0                              76.18
# 1                               6547182.0                              67.58
# 2                               6063147.0                              62.68
# 3                               5580047.0                              57.82
# 4                               5098299.0                              53.00
# ...                                   ...                                ...
# 2085                            1345405.0                              15.97
# 2086                             942929.0                              12.28
# 2087                             588185.0                               9.03
# 2088                             305948.0                               6.41
# 2089                            8148871.0                              81.49
#
#       lx - number of people left alive at age x  \
# 0                                       97402.0
# 1                                       96875.0
# 2                                       96739.0
# 3                                       96502.0
# 4                                       96197.0
# ...                                         ...
# 2085                                    84223.0
# 2086                                    76768.0
# 2087                                    65130.0
# 2088                                    47765.0
# 2089                                   100000.0
#
#       nLx - person-years lived between ages x and x+n  \
# 0                                            388666.0
# 1                                            484035.0
# 2                                            483101.0
# 3                                            481748.0
# 4                                            480046.0
# ...                                               ...
# 2085                                         402477.0
# 2086                                         354743.0
# 2087                                         282238.0
# 2088                                         305948.0
# 2089                                          99823.0
#
#       nMx - age-specific death rate between ages x and x+n  \
# 0                                                0.0010
# 1                                                0.0003
# 2                                                0.0005
# 3                                                0.0006
# 4                                                0.0008
# ...                                                 ...
# 2085                                             0.0190
# 2086                                             0.0330
# 2087                                             0.0620
# 2088                                             0.1400
# 2089                                             0.0020
#
#       ndx - number of people dying between ages x and x+n  \
# 0                                                 392.3
# 1                                                 137.0
# 2                                                 236.7
# 3                                                 304.5
# 4                                                 376.4
# ...                                                 ...
# 2085                                             7455.0
# 2086                                            11638.0
# 2087                                            17364.0
# 2088                                            47765.0
# 2089                                              196.4
#
#       nqx - probability of dying between ages x and x+n            GDP
# 0                                                 0.004  1653572400000
# 1                                                 0.001  1653572400000
# 2                                                 0.002  1653572400000
# 3                                                 0.003  1653572400000
# 4                                                 0.004  1653572400000
# ...                                                 ...            ...
# 2085                                              0.089  5036891000000
# 2086                                              0.150  5036891000000
# 2087                                              0.270  5036891000000
# 2088                                              1.000  5036891000000
# 2089                                              0.002  5036891000000
#
# [2090 rows x 14 columns]

# %%
nc_df = pd.read_csv("NonCommunicable_Disease_dataset.csv")
nc_df
# Out:
#           IndicatorCode                                          Indicator  \
# 0      SDG_SH_DTH_RNCOM  Number of deaths attributed to non-communicabl...
# 1      SDG_SH_DTH_RNCOM  Number of deaths attributed to non-communicabl...
# 2      SDG_SH_DTH_RNCOM  Number of deaths attributed to non-communicabl...
# 3      SDG_SH_DTH_RNCOM  Number of deaths attributed to non-communicabl...
# 4      SDG_SH_DTH_RNCOM  Number of deaths attributed to non-communicabl...
# ...                 ...                                                ...
# 43915  SDG_SH_DTH_RNCOM  Number of deaths attributed to non-communicabl...
# 43916  SDG_SH_DTH_RNCOM  Number of deaths attributed to non-communicabl...
# 43917  SDG_SH_DTH_RNCOM  Number of deaths attributed to non-communicabl...
# 43918  SDG_SH_DTH_RNCOM  Number of deaths attributed to non-communicabl...
# 43919  SDG_SH_DTH_RNCOM  Number of deaths attributed to non-communicabl...
#
#       ValueType ParentLocationCode   ParentLocation Location type  \
# 0       numeric                EUR           Europe       Country
# 1       numeric                WPR  Western Pacific       Country
# 2       numeric               SEAR  South-East Asia       Country
# 3       numeric               SEAR  South-East Asia       Country
# 4       numeric               SEAR  South-East Asia       Country
# ...         ...                ...              ...           ...
# 43915   numeric                AFR           Africa       Country
# 43916   numeric                WPR  Western Pacific       Country
# 43917   numeric               SEAR  South-East Asia       Country
# 43918   numeric                AFR           Africa       Country
# 43919   numeric                EUR           Europe       Country
#
#       SpatialDimValueCode            Location Period type  Period  ...  \
# 0                     RUS  Russian Federation        Year    2019  ...
# 1                     CHN               China        Year    2019  ...
# 2                     IND               India        Year    2019  ...
# 3                     IND               India        Year    2019  ...
# 4                     IND               India        Year    2019  ...
# ...                   ...                 ...         ...     ...  ...
# 43915                 SYC          Seychelles        Year    2000  ...
# 43916                 SLB     Solomon Islands        Year    2000  ...
# 43917                 MDV            Maldives        Year    2000  ...
# 43918                 BFA        Burkina Faso        Year    2000  ...
# 43919                 PRT            Portugal        Year    2000  ...
#
#        FactValueUoM FactValueNumericLowPrefix FactValueNumericLow  \
# 0               NaN                       NaN           797625.00
# 1               NaN                       NaN           807008.00
# 2               NaN                       NaN           821773.00
# 3               NaN                       NaN           765727.00
# 4               NaN                       NaN          1111032.00
# ...             ...                       ...                 ...
# 43915           NaN                       NaN               72.37
# 43916           NaN                       NaN               55.73
# 43917           NaN                       NaN               60.51
# 43918           NaN                       NaN              520.40
# 43919           NaN                       NaN             8322.00
#
#       FactValueNumericHighPrefix FactValueNumericHigh  \
# 0                            NaN            1203905.0
# 1                            NaN            1299036.0
# 2                            NaN            1436096.0
# 3                            NaN            1535106.0
# 4                            NaN            1849975.0
# ...                          ...                  ...
# 43915                        NaN                128.6
# 43916                        NaN                164.5
# 43917                        NaN                155.4
# 43918                        NaN               1683.0
# 43919                        NaN              11792.0
#
#                                            Value FactValueTranslationID  \
# 0         1 003 695 [797 625 – 1 203 905]                    NaN
# 1         1 013 621 [807 008 – 1 299 036]                    NaN
# 2         1 115 687 [821 773 – 1 436 096]                    NaN
# 3         1 146 371 [765 727 – 1 535 106]                    NaN
# 4      1 450 806 [1 111 032 – 1 849 975]                    NaN
# ...                                          ...                    ...
# 43915                    99.05 [72.37 – 128.6]                    NaN
# 43916                     99.3 [55.73 – 164.5]                    NaN
# 43917                    99.62 [60.51 – 155.4]                    NaN
# 43918                     990.5 [520.4 – 1683]                    NaN
# 43919                    9993 [8322 – 11 792]                    NaN
#
#        FactComments  Language              DateModified
# 0               NaN        EN  2021-02-09T08:00:00.000Z
# 1               NaN        EN  2021-02-09T08:00:00.000Z
# 2               NaN        EN  2021-02-09T08:00:00.000Z
# 3               NaN        EN  2021-02-09T08:00:00.000Z
# 4               NaN        EN  2021-02-09T08:00:00.000Z
# ...             ...       ...                       ...
# 43915           NaN        EN  2021-02-09T08:00:00.000Z
# 43916           NaN        EN  2021-02-09T08:00:00.000Z
# 43917           NaN        EN  2021-02-09T08:00:00.000Z
# 43918           NaN        EN  2021-02-09T08:00:00.000Z
# 43919           NaN        EN  2021-02-09T08:00:00.000Z
#
# [43920 rows x 34 columns]

# %%
nc_df= nc_df[['ParentLocationCode','SpatialDimValueCode','Location','Period','Dim1','Dim2','FactValueNumeric','FactValueNumericLow','FactValueNumericHigh']]
nc_df
# Out:
#       ParentLocationCode SpatialDimValueCode            Location  Period  \
# 0                    EUR                 RUS  Russian Federation    2019
# 1                    WPR                 CHN               China    2019
# 2                   SEAR                 IND               India    2019
# 3                   SEAR                 IND               India    2019
# 4                   SEAR                 IND               India    2019
# ...                  ...                 ...                 ...     ...
# 43915                AFR                 SYC          Seychelles    2000
# 43916                WPR                 SLB     Solomon Islands    2000
# 43917               SEAR                 MDV            Maldives    2000
# 43918                AFR                 BFA        Burkina Faso    2000
# 43919                EUR                 PRT            Portugal    2000
#
#              Dim1                     Dim2  FactValueNumeric  \
# 0      Both sexes  Cardiovascular diseases        1003695.00
# 1      Both sexes     Respiratory diseases        1013621.00
# 2          Female  Cardiovascular diseases        1115687.00
# 3      Both sexes     Respiratory diseases        1146371.00
# 4            Male  Cardiovascular diseases        1450806.00
# ...           ...                      ...               ...
# 43915      Female  Cardiovascular diseases             99.05
# 43916        Male     Respiratory diseases             99.30
# 43917        Male      Malignant neoplasms             99.62
# 43918      Female     Respiratory diseases            990.50
# 43919      Female      Malignant neoplasms           9993.00
#
#        FactValueNumericLow  FactValueNumericHigh
# 0                797625.00             1203905.0
# 1                807008.00             1299036.0
# 2                821773.00             1436096.0
# 3                765727.00             1535106.0
# 4               1111032.00             1849975.0
# ...                    ...                   ...
# 43915                72.37                 128.6
# 43916                55.73                 164.5
# 43917                60.51                 155.4
# 43918               520.40                1683.0
# 43919              8322.00               11792.0
#
# [43920 rows x 9 columns]

# %%
nc_df.IsLatestYear.unique()
# Out:
# array([ True, False])

# %%
nc_df.columns
# Out:
# Index(['IndicatorCode', 'Indicator', 'ValueType', 'ParentLocationCode',
#        'ParentLocation', 'Location type', 'SpatialDimValueCode', 'Location',
#        'Period type', 'Period', 'IsLatestYear', 'Dim1 type', 'Dim1',
#        'Dim1ValueCode', 'Dim2 type', 'Dim2', 'Dim2ValueCode', 'Dim3 type',
#        'Dim3', 'Dim3ValueCode', 'DataSourceDimValueCode', 'DataSource',
#        'FactValueNumericPrefix', 'FactValueNumeric', 'FactValueUoM',
#        'FactValueNumericLowPrefix', 'FactValueNumericLow',
#        'FactValueNumericHighPrefix', 'FactValueNumericHigh', 'Value',
#        'FactValueTranslationID', 'FactComments', 'Language', 'DateModified'],
#       dtype='object')

# %%
both_sexes_mask = nc_df['Dim1'] == 'Both sexes'

# Create separate DataFrames for 'Male' and 'Female'
df_male = nc_df.copy()
df_female = nc_df.copy()

# Update 'Dim1' column in each DataFrame
df_male.loc[both_sexes_mask, 'Dim1'] = 'Male'
df_female.loc[both_sexes_mask, 'Dim1'] = 'Female'

# Concatenate the three DataFrames
df_result = pd.concat([nc_df[~both_sexes_mask], df_male[both_sexes_mask], df_female[both_sexes_mask]])
df_result = df_result.rename(columns={'Dim1':'Sex','Dim2':'non-communicable_diseases','ParentLocationCode':'Region_Code'})
# Reset index
df_result.reset_index(drop=True, inplace=True)
df_result
# Out:
#       Region_Code SpatialDimValueCode                          Location  \
# 0            SEAR                 IND                             India
# 1            SEAR                 IND                             India
# 2             WPR                 CHN                             China
# 3             WPR                 CHN                             China
# 4             AFR                 ZWE                          Zimbabwe
# ...           ...                 ...                               ...
# 58555         AFR                 COD  Democratic Republic of the Congo
# 58556         EUR                 BIH            Bosnia and Herzegovina
# 58557         EUR                 MLT                             Malta
# 58558         EUR                 LUX                        Luxembourg
# 58559         EMR                 IRN        Iran (Islamic Republic of)
#
#        Period     Sex non-communicable_diseases  FactValueNumeric  \
# 0        2019  Female   Cardiovascular diseases        1115687.00
# 1        2019    Male   Cardiovascular diseases        1450806.00
# 2        2019    Male       Malignant neoplasms        1659677.00
# 3        2019  Female   Cardiovascular diseases        1877096.00
# 4        2019  Female   Cardiovascular diseases          10035.00
# ...       ...     ...                       ...               ...
# 58555    2000  Female         Diabetes mellitus           9705.00
# 58556    2000  Female         Diabetes mellitus            974.70
# 58557    2000  Female         Diabetes mellitus             98.27
# 58558    2000  Female       Malignant neoplasms            982.60
# 58559    2000  Female      Respiratory diseases           9853.00
#
#        FactValueNumericLow  FactValueNumericHigh
# 0                821773.00             1436096.0
# 1               1111032.00             1849975.0
# 2               1277365.00             2086563.0
# 3               1463568.00             2282684.0
# 4                  6031.00               15524.0
# ...                    ...                   ...
# 58555              5899.00               14976.0
# 58556               657.20                1384.0
# 58557                72.79                 130.2
# 58558               783.50                1206.0
# 58559              7924.00               12287.0
#
# [58560 rows x 9 columns]

# %%
df_result = df_result.groupby(['Region_Code','SpatialDimValueCode','Location', 'Period','Sex','non-communicable_diseases'], as_index=False)[['FactValueNumeric','FactValueNumericLow','FactValueNumericHigh']].sum()
df_result=df_result[df_result['Location'].isin(ten_economies)]
df_result
# Out:
#       Region_Code SpatialDimValueCode Location  Period     Sex  \
# 8320          AMR                 BRA   Brazil    2000  Female
# 8321          AMR                 BRA   Brazil    2000  Female
# 8322          AMR                 BRA   Brazil    2000  Female
# 8323          AMR                 BRA   Brazil    2000  Female
# 8324          AMR                 BRA   Brazil    2000    Male
# ...           ...                 ...      ...     ...     ...
# 26875         WPR                 JPN    Japan    2019  Female
# 26876         WPR                 JPN    Japan    2019    Male
# 26877         WPR                 JPN    Japan    2019    Male
# 26878         WPR                 JPN    Japan    2019    Male
# 26879         WPR                 JPN    Japan    2019    Male
#
#       non-communicable_diseases  FactValueNumeric  FactValueNumericLow  \
# 8320    Cardiovascular diseases          442596.0             386808.0
# 8321          Diabetes mellitus           65949.0              56471.0
# 8322        Malignant neoplasms          207022.0             184424.0
# 8323       Respiratory diseases          111660.0              90305.0
# 8324    Cardiovascular diseases          459255.0             405489.0
# ...                         ...               ...                  ...
# 26875      Respiratory diseases          183848.0             111046.0
# 26876   Cardiovascular diseases          528323.0             409896.0
# 26877         Diabetes mellitus           23543.0              16425.0
# 26878       Malignant neoplasms          634851.0             520942.0
# 26879      Respiratory diseases          205936.0             129745.0
#
#        FactValueNumericHigh
# 8320               487343.0
# 8321                75314.0
# 8322               228142.0
# 8323               123246.0
# 8324               504280.0
# ...                     ...
# 26875              268100.0
# 26876              615647.0
# 26877               30587.0
# 26878              713168.0
# 26879              286514.0
#
# [1760 rows x 9 columns]

# %%
# Out:
#      Region_Code SpatialDimValueCode Location  Period     Sex  \
# 0            AMR                 BRA   Brazil    2000  Female
# 1            AMR                 BRA   Brazil    2000  Female
# 2            AMR                 BRA   Brazil    2000  Female
# 3            AMR                 BRA   Brazil    2000  Female
# 4            AMR                 BRA   Brazil    2000    Male
# ...          ...                 ...      ...     ...     ...
# 1755         WPR                 JPN    Japan    2019  Female
# 1756         WPR                 JPN    Japan    2019    Male
# 1757         WPR                 JPN    Japan    2019    Male
# 1758         WPR                 JPN    Japan    2019    Male
# 1759         WPR                 JPN    Japan    2019    Male
#
#       FactValueNumeric  FactValueNumericLow  FactValueNumericHigh  \
# 0             442596.0             386808.0              487343.0
# 1              65949.0              56471.0               75314.0
# 2             207022.0             184424.0              228142.0
# 3             111660.0              90305.0              123246.0
# 4             459255.0             405489.0              504280.0
# ...                ...                  ...                   ...
# 1755          183848.0             111046.0              268100.0
# 1756          528323.0             409896.0              615647.0
# 1757           23543.0              16425.0               30587.0
# 1758          634851.0             520942.0              713168.0
# 1759          205936.0             129745.0              286514.0
#
#       non-communicable_diseases_Cardiovascular diseases  \
# 0                                                     1
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     1
# ...                                                 ...
# 1755                                                  0
# 1756                                                  1
# 1757                                                  0
# 1758                                                  0
# 1759                                                  0
#
#       non-communicable_diseases_Diabetes mellitus  \
# 0                                               0
# 1                                               1
# 2                                               0
# 3                                               0
# 4                                               0
# ...                                           ...
# 1755                                            0
# 1756                                            0
# 1757                                            1
# 1758                                            0
# 1759                                            0
#
#       non-communicable_diseases_Malignant neoplasms  \
# 0                                                 0
# 1                                                 0
# 2                                                 1
# 3                                                 0
# 4                                                 0
# ...                                             ...
# 1755                                              0
# 1756                                              0
# 1757                                              0
# 1758                                              1
# 1759                                              0
#
#       non-communicable_diseases_Respiratory diseases
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  1
# 4                                                  0
# ...                                              ...
# 1755                                               1
# 1756                                               0
# 1757                                               0
# 1758                                               0
# 1759                                               1
#
# [1760 rows x 12 columns]

# %%
df_result=df_result.reset_index(drop=True)
df_result
# Out:
#      Region_Code SpatialDimValueCode Location  Period     Sex  \
# 0            AMR                 BRA   Brazil    2000  Female
# 1            AMR                 BRA   Brazil    2000  Female
# 2            AMR                 BRA   Brazil    2000  Female
# 3            AMR                 BRA   Brazil    2000  Female
# 4            AMR                 BRA   Brazil    2000    Male
# ...          ...                 ...      ...     ...     ...
# 1755         WPR                 JPN    Japan    2019  Female
# 1756         WPR                 JPN    Japan    2019    Male
# 1757         WPR                 JPN    Japan    2019    Male
# 1758         WPR                 JPN    Japan    2019    Male
# 1759         WPR                 JPN    Japan    2019    Male
#
#      non-communicable_diseases  FactValueNumeric  FactValueNumericLow  \
# 0      Cardiovascular diseases          442596.0             386808.0
# 1            Diabetes mellitus           65949.0              56471.0
# 2          Malignant neoplasms          207022.0             184424.0
# 3         Respiratory diseases          111660.0              90305.0
# 4      Cardiovascular diseases          459255.0             405489.0
# ...                        ...               ...                  ...
# 1755      Respiratory diseases          183848.0             111046.0
# 1756   Cardiovascular diseases          528323.0             409896.0
# 1757         Diabetes mellitus           23543.0              16425.0
# 1758       Malignant neoplasms          634851.0             520942.0
# 1759      Respiratory diseases          205936.0             129745.0
#
#       FactValueNumericHigh
# 0                 487343.0
# 1                  75314.0
# 2                 228142.0
# 3                 123246.0
# 4                 504280.0
# ...                    ...
# 1755              268100.0
# 1756              615647.0
# 1757               30587.0
# 1758              713168.0
# 1759              286514.0
#
# [1760 rows x 9 columns]

# %%
# df_result.to_csv('non-communicable_deseases.csv', index=True)

# %%
# Out:
#            Age_Child  Age_Teen  Gender_Male  Prescription_Myope  \
# Patient #
# 1                  0         0            1                   1
# 2                  1         0            0                   0
# 3                  0         1            1                   0
#
#            Prescription_Normal  Condition_Normal  Condition_Strong  \
# Patient #
# 1                            0                 0                 0
# 2                            0                 0                 1
# 3                            1                 1                 0
#
#            Astigmatic_Yes  Tear Production_Reduced
# Patient #
# 1                       1                        1
# 2                       0                        0
# 3                       0                        1

# %%
# Out:
# The Simple Matching Coefficient distance between objects 1 and 2 is: 1.00
